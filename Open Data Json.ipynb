# %% [markdown]
# ## Open Data Json

# %%
#memasukan modul yang digunakan
import json

#membuka data
with open('kota_kabupaten.geojson') as f:
    data = json.load(f)

# %%
#melihat isi data 
data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[106.741523942441, -6.71556328298331],
#        [106.742338058058, -6.71632093342634],
#        [106.746023161083, -6.7180910026616],
#        [106.746826834641, -6.7187937247613],
#        [106.752653463573, -6.72388845543899],
#        [106.756357431948, -6.72664495406536],
#        [106.75778409481, -6.72754643060876],
#        [106.761503886222, -6.73331493177422],
#        [106.762729175293, -6.736211877764],
#        [106.762949760681, -6.73627751500813],
#        [106.763295386501, -6.73641164681981],
#        [106.763436635501, -6.73647505927963],
#        [106.763765770918, -6.7365752690773],
#        [106.764126318975, -6.73665788361551],
#        [106.764255979401, -6.73672734596794],
#        [106.764291144921, -6.73677966537606],
#        [106.764294919561, -6.73685657540808],
#        [106.764207786118, -6.73694080680625],
# ...

# %% [markdown]
#                                     ##Semoga Bermanfaat
#                                     ##@Raspiani_
